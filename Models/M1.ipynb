# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('solar.csv')

# %%
data.head()
# Out:
#    Day of Year  Year  Month  Day  First Hour of Period  Is Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
#
#    Distance to Solar Noon  Average Temperature (Day)  \
# 0                0.859897                         69
# 1                0.628535                         69
# 2                0.397172                         69
# 3                0.165810                         69
# 4                0.065553                         69
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# 2                            28                       7.5          0
# 3                            28                       7.5          0
# 4                            28                       7.5          0
#
#    Visibility  Relative Humidity  Average Wind Speed (Period)  \
# 0        10.0                 75                          8.0
# 1        10.0                 77                          5.0
# 2        10.0                 70                          0.0
# 3        10.0                 33                          0.0
# 4        10.0                 21                          3.0
#
#    Average Barometric Pressure (Period)  Power Generated
# 0                                 29.82                0
# 1                                 29.85                0
# 2                                 29.89             5418
# 3                                 29.91            25477
# 4                                 29.89            30069

# %%
data.shape
# Out:
# (2920, 16)

# %%
data.isnull().sum()
# Out:
# Day of Year                             0
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Distance to Solar Noon                  0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             1
# Average Barometric Pressure (Period)    0
# Power Generated                         0
# dtype: int64

# %%
df = data.dropna()

# %%
df.head()
# Out:
#    Day of Year  Year  Month  Day  First Hour of Period  Is Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
#
#    Distance to Solar Noon  Average Temperature (Day)  \
# 0                0.859897                         69
# 1                0.628535                         69
# 2                0.397172                         69
# 3                0.165810                         69
# 4                0.065553                         69
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# 2                            28                       7.5          0
# 3                            28                       7.5          0
# 4                            28                       7.5          0
#
#    Visibility  Relative Humidity  Average Wind Speed (Period)  \
# 0        10.0                 75                          8.0
# 1        10.0                 77                          5.0
# 2        10.0                 70                          0.0
# 3        10.0                 33                          0.0
# 4        10.0                 21                          3.0
#
#    Average Barometric Pressure (Period)  Power Generated
# 0                                 29.82                0
# 1                                 29.85                0
# 2                                 29.89             5418
# 3                                 29.91            25477
# 4                                 29.89            30069

# %%
df.shape
# Out:
# (2919, 16)

# %%
df.columns
# Out:
# Index(['Day of Year', 'Year', 'Month', 'Day', 'First Hour of Period',
#        'Is Daylight', 'Distance to Solar Noon', 'Average Temperature (Day)',
#        'Average Wind Direction (Day)', 'Average Wind Speed (Day)', 'Sky Cover',
#        'Visibility', 'Relative Humidity', 'Average Wind Speed (Period)',
#        'Average Barometric Pressure (Period)', 'Power Generated'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 2919
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Day of Year                           2919 non-null   int64
#  1   Year                                  2919 non-null   int64
#  2   Month                                 2919 non-null   int64
#  3   Day                                   2919 non-null   int64
#  4   First Hour of Period                  2919 non-null   int64
#  5   Is Daylight                           2919 non-null   bool
#  6   Distance to Solar Noon                2919 non-null   float64
#  7   Average Temperature (Day)             2919 non-null   int64
#  8   Average Wind Direction (Day)          2919 non-null   int64
#  9   Average Wind Speed (Day)              2919 non-null   float64
#  10  Sky Cover                             2919 non-null   int64
#  11  Visibility                            2919 non-null   float64
#  12  Relative Humidity                     2919 non-null   int64
#  13  Average Wind Speed (Period)           2919 non-null   float64
#  14  Average Barometric Pressure (Period)  2919 non-null   float64
#  15  Power Generated                       2919 non-null   int64
# dtypes: bool(1), float64(5), int64(10)
# memory usage: 367.7 KB

# %%
df.describe()
# Out:
#        Day of Year         Year        Month          Day  \
# count  2919.000000  2919.000000  2919.000000  2919.000000
# mean    183.282631  2008.665982     6.524495    15.715999
# std     105.751253     0.471727     3.448038     8.795825
# min       1.000000  2008.000000     1.000000     1.000000
# 25%      92.000000  2008.000000     4.000000     8.000000
# 50%     183.000000  2009.000000     7.000000    16.000000
# 75%     275.000000  2009.000000    10.000000    23.000000
# max     366.000000  2009.000000    12.000000    31.000000
#
#        First Hour of Period  Distance to Solar Noon  \
# count           2919.000000             2919.000000
# mean              11.501542                0.503327
# std                6.875714                0.298069
# min                1.000000                0.050401
# 25%                5.500000                0.232061
# 50%               13.000000                0.479241
# 75%               17.500000                0.739559
# max               22.000000                1.141361
#
#        Average Temperature (Day)  Average Wind Direction (Day)  \
# count                2919.000000                   2919.000000
# mean                   58.468996                     24.957862
# std                     6.842318                      6.912203
# min                    42.000000                      1.000000
# 25%                    53.000000                     25.000000
# 50%                    59.000000                     27.000000
# 75%                    63.000000                     29.000000
# max                    78.000000                     36.000000
#
#        Average Wind Speed (Day)    Sky Cover   Visibility  Relative Humidity  \
# count               2919.000000  2919.000000  2919.000000        2919.000000
# mean                  10.099486     1.987667     9.559609          73.505995
# std                    4.837128     1.412220     1.380290          15.073974
# min                    1.100000     0.000000     0.000000          14.000000
# 25%                    6.600000     1.000000    10.000000          65.000000
# 50%                   10.000000     2.000000    10.000000          77.000000
# 75%                   13.100000     3.000000    10.000000          84.000000
# max                   26.600000     4.000000    10.000000         100.000000
#
#        Average Wind Speed (Period)  Average Barometric Pressure (Period)  \
# count                  2919.000000                           2919.000000
# mean                     10.129154                             30.017712
# std                       7.261547                              0.142006
# min                       0.000000                             29.480000
# 25%                       5.000000                             29.920000
# 50%                       9.000000                             30.000000
# 75%                      15.000000                             30.110000
# max                      40.000000                             30.530000
#
#        Power Generated
# count      2919.000000
# mean       6982.182939
# std       10313.330078
# min           0.000000
# 25%           0.000000
# 50%         404.000000
# 75%       12725.000000
# max       36580.000000

# %%
df.isnull().sum()
# Out:
# Day of Year                             0
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Distance to Solar Noon                  0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# Power Generated                         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Day of Year                             0
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Distance to Solar Noon                  0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# Power Generated                         0
# dtype: int64

# %%
df = df.rename(columns={'Day of Year':'Day_of_Year','Is Daylight':'Is_Daylight','First Hour of Period':'First_Hour_of_Period','Is Daylight':'Is_Daylight','Distance to Solar Noon':'Distance_to_Solar_Noon','Average Temperature (Day)':'Average_Temperature','Average Wind Direction (Day)':'Average_Wind_Direction','Average Wind Speed (Day)':'Average_Wind_Speed','Sky Cover':'Sky_Cover','Relative Humidity':'Relative_Humidity','Average Wind Speed (Period)':'Average_Wind_Speed','Average Barometric Pressure (Period)':'Average_Barometric_Pressure','Power Generated':'Power_Generated'})

# %%
df.columns
# Out:
# Index(['Day_of_Year', 'Year', 'Month', 'Day', 'First_Hour_of_Period',
#        'Is_Daylight', 'Distance_to_Solar_Noon', 'Average_Temperature',
#        'Average_Wind_Direction', 'Average_Wind_Speed', 'Sky_Cover',
#        'Visibility', 'Relative_Humidity', 'Average_Wind_Speed',
#        'Average_Barometric_Pressure', 'Power_Generated'],
#       dtype='object')

# %%
df.First_Hour_of_Period.unique()
# Out:
# array([ 1,  4,  7, 10, 13, 16, 19, 22], dtype=int64)

# %%
df.Is_Daylight.unique()
# Out:
# array([False,  True])

# %%
df.Distance_to_Solar_Noon.unique()
# Out:
# array([0.85989717, 0.6285347 , 0.39717224, ..., 0.29449424, 0.52496799,
#        0.75544174])

# %%
df.corr()
# Out:
#                              Day_of_Year      Year     Month       Day  \
# Day_of_Year                     1.000000 -0.818412  0.996520  0.094129
# Year                           -0.818412  1.000000 -0.818255 -0.001974
# Month                           0.996520 -0.818255  1.000000  0.011230
# Day                             0.094129 -0.001974  0.011230  1.000000
# First_Hour_of_Period            0.000320 -0.000317  0.000291  0.000339
# Is_Daylight                    -0.055288  0.087559 -0.055260  0.004517
# Distance_to_Solar_Noon          0.044453 -0.135724  0.043132 -0.000434
# Average_Temperature             0.257789 -0.046688  0.263076 -0.021992
# Average_Wind_Direction          0.192094  0.005246  0.186718  0.111685
# Average_Wind_Speed             -0.088287  0.304131 -0.081456 -0.035234
# Sky_Cover                      -0.052670  0.092584 -0.048429 -0.050991
# Visibility                     -0.004226  0.089275 -0.004915  0.027752
# Relative_Humidity               0.031508 -0.003405  0.028697  0.031739
# Average_Wind_Speed             -0.073227  0.214389 -0.068733 -0.023474
# Average_Barometric_Pressure    -0.122886 -0.069480 -0.128667  0.037990
# Power_Generated                -0.037070  0.122813 -0.036304  0.007063
#
#                              First_Hour_of_Period  Is_Daylight  \
# Day_of_Year                              0.000320    -0.055288
# Year                                    -0.000317     0.087559
# Month                                    0.000291    -0.055260
# Day                                      0.000339     0.004517
# First_Hour_of_Period                     1.000000     0.173255
# Is_Daylight                              0.173255     1.000000
# Distance_to_Solar_Noon                  -0.062237    -0.827087
# Average_Temperature                     -0.000048     0.067295
# Average_Wind_Direction                  -0.000420     0.056829
# Average_Wind_Speed                      -0.000338     0.060376
# Sky_Cover                               -0.073585     0.028588
# Visibility                               0.049903    -0.086235
# Relative_Humidity                       -0.251581    -0.341510
# Average_Wind_Speed                       0.289482     0.192290
# Average_Barometric_Pressure             -0.033481    -0.054039
# Power_Generated                          0.107209     0.532336
#
#                              Distance_to_Solar_Noon  Average_Temperature  \
# Day_of_Year                                0.044453             0.257789
# Year                                      -0.135724            -0.046688
# Month                                      0.043132             0.263076
# Day                                       -0.000434            -0.021992
# First_Hour_of_Period                      -0.062237            -0.000048
# Is_Daylight                               -0.827087             0.067295
# Distance_to_Solar_Noon                     1.000000            -0.145235
# Average_Temperature                       -0.145235             1.000000
# Average_Wind_Direction                    -0.118293             0.342216
# Average_Wind_Speed                        -0.145301             0.096194
# Sky_Cover                                 -0.015183            -0.230673
# Visibility                                 0.065541             0.194354
# Relative_Humidity                          0.369278            -0.221440
# Average_Wind_Speed                        -0.214891             0.054546
# Average_Barometric_Pressure                0.082633            -0.435728
# Power_Generated                           -0.746825             0.132155
#
#                              Average_Wind_Direction  Average_Wind_Speed  \
# Day_of_Year                                0.192094           -0.088287
# Year                                       0.005246            0.304131
# Month                                      0.186718           -0.081456
# Day                                        0.111685           -0.035234
# First_Hour_of_Period                      -0.000420           -0.000338
# Is_Daylight                                0.056829            0.060376
# Distance_to_Solar_Noon                    -0.118293           -0.145301
# Average_Temperature                        0.342216            0.096194
# Average_Wind_Direction                     1.000000            0.340899
# Average_Wind_Speed                         0.340899            1.000000
# Sky_Cover                                 -0.137217            0.107840
# Visibility                                 0.201546            0.183281
# Relative_Humidity                         -0.095053            0.005676
# Average_Wind_Speed                         0.229844            0.673626
# Average_Barometric_Pressure               -0.271973           -0.379447
# Power_Generated                            0.146463            0.142366
#
#                              Sky_Cover  Visibility  Relative_Humidity  \
# Day_of_Year                  -0.052670   -0.004226           0.031508
# Year                          0.092584    0.089275          -0.003405
# Month                        -0.048429   -0.004915           0.028697
# Day                          -0.050991    0.027752           0.031739
# First_Hour_of_Period         -0.073585    0.049903          -0.251581
# Is_Daylight                   0.028588   -0.086235          -0.341510
# Distance_to_Solar_Noon       -0.015183    0.065541           0.369278
# Average_Temperature          -0.230673    0.194354          -0.221440
# Average_Wind_Direction       -0.137217    0.201546          -0.095053
# Average_Wind_Speed            0.107840    0.183281           0.005676
# Sky_Cover                     1.000000   -0.224131           0.394722
# Visibility                   -0.224131    1.000000          -0.290180
# Relative_Humidity             0.394722   -0.290180           1.000000
# Average_Wind_Speed            0.044301    0.143621          -0.218042
# Average_Barometric_Pressure  -0.091531   -0.104273           0.017987
# Power_Generated              -0.187248    0.075841          -0.522445
#
#                              Average_Wind_Speed  Average_Barometric_Pressure  \
# Day_of_Year                           -0.073227                    -0.122886
# Year                                   0.214389                    -0.069480
# Month                                 -0.068733                    -0.128667
# Day                                   -0.023474                     0.037990
# First_Hour_of_Period                   0.289482                    -0.033481
# Is_Daylight                            0.192290                    -0.054039
# Distance_to_Solar_Noon                -0.214891                     0.082633
# Average_Temperature                    0.054546                    -0.435728
# Average_Wind_Direction                 0.229844                    -0.271973
# Average_Wind_Speed                     0.673626                    -0.379447
# Sky_Cover                              0.044301                    -0.091531
# Visibility                             0.143621                    -0.104273
# Relative_Humidity                     -0.218042                     0.017987
# Average_Wind_Speed                     1.000000                    -0.293457
# Average_Barometric_Pressure           -0.293457                     1.000000
# Power_Generated                        0.278174                    -0.036553
#
#                              Power_Generated
# Day_of_Year                        -0.037070
# Year                                0.122813
# Month                              -0.036304
# Day                                 0.007063
# First_Hour_of_Period                0.107209
# Is_Daylight                         0.532336
# Distance_to_Solar_Noon             -0.746825
# Average_Temperature                 0.132155
# Average_Wind_Direction              0.146463
# Average_Wind_Speed                  0.142366
# Sky_Cover                          -0.187248
# Visibility                          0.075841
# Relative_Humidity                  -0.522445
# Average_Wind_Speed                  0.278174
# Average_Barometric_Pressure        -0.036553
# Power_Generated                     1.000000

# %%
x = df.Average_Temperature.mean()
print('Average_Temperature mean value:',x)
# Out:
# Average_Temperature mean value: 58.46899623158616

# %%
x = df.Average_Wind_Direction.mean()
print('Average_Wind_Direction mean value:',x)
# Out:
# Average_Wind_Direction mean value: 24.95786228160329

# %%
x = df.Average_Wind_Speed.mean()
print('Average_Wind_Speed mean value:',x)
# Out:
# Average_Wind_Speed mean value: Average_Wind_Speed    10.099486
# Average_Wind_Speed    10.129154
# dtype: float64

# %%
x = df.Sky_Cover.mean()
print('Sky_Cover mean value:',x)
# Out:
# Sky_Cover mean value: 1.987667009249743

# %%
y = df.Power_Generated.unique().sum()
print('Total of Power_Generated:',y)
# Out:
# Total of Power_Generated: 19930889

# %%
df.head()
# Out:
#    Day_of_Year  Year  Month  Day  First_Hour_of_Period  Is_Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
#
#    Distance_to_Solar_Noon  Average_Temperature  Average_Wind_Direction  \
# 0                0.859897                   69                      28
# 1                0.628535                   69                      28
# 2                0.397172                   69                      28
# 3                0.165810                   69                      28
# 4                0.065553                   69                      28
#
#    Average_Wind_Speed  Sky_Cover  Visibility  Relative_Humidity  \
# 0                 7.5          0        10.0                 75
# 1                 7.5          0        10.0                 77
# 2                 7.5          0        10.0                 70
# 3                 7.5          0        10.0                 33
# 4                 7.5          0        10.0                 21
#
#    Average_Wind_Speed  Average_Barometric_Pressure  Power_Generated
# 0                 8.0                        29.82                0
# 1                 5.0                        29.85                0
# 2                 0.0                        29.89             5418
# 3                 0.0                        29.91            25477
# 4                 3.0                        29.89            30069

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2915    False
# 2916    False
# 2917    False
# 2918    False
# 2919    False
# Length: 2919, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0
